# %%
import os
import matplotlib.pyplot as plt
import scanpy as sc
import torch
import time
import json
import scvi
import numpy as np

# %%
sc.set_figure_params(figsize=(4, 4))

# %% [markdown]
# # Set Params

# %%
deep_inject = False
n_epochs_surgery = 300
leave_out_cell_types = ['NK cells']

# %%
target_batches = ["10X"]
batch_key = "condition"
cell_type_key = "final_annotation"

# %%
n_epochs_vae = 500
n_epochs_scanvi = 300
early_stopping_kwargs = {
    "early_stopping_metric": "elbo",
    "save_best_state_metric": "elbo",
    "patience": 10,
    "threshold": 0,
    "reduce_lr_on_plateau": True,
    "lr_patience": 8,
    "lr_factor": 0.1,
}
early_stopping_kwargs_scanvi = {
    "early_stopping_metric": "accuracy",
    "save_best_state_metric": "accuracy",
    "on": "full_dataset",
    "patience": 10,
    "threshold": 0.001,
    "reduce_lr_on_plateau": True,
    "lr_patience": 8,
    "lr_factor": 0.1,
}

# %%
# Save right dir path
if len(leave_out_cell_types) > 1:
    version = "ood_2"
else:
    version = "ood_1"
if deep_inject:
    dir_path = os.path.expanduser(f'~/Documents/benchmarking_results/figure_5/scanvi/{version}_deep_cond/')
else:
    dir_path = os.path.expanduser(f'~/Documents/benchmarking_results/figure_5/scanvi/{version}_first_cond/')
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

# %% [markdown]
# # Adata Handling

# %%
adata_all = sc.read(os.path.expanduser(f'~/Documents/benchmarking_datasets/Immune_ALL_human_wo_villani_normalized_hvg.h5ad'))
adata = adata_all.raw.to_adata()
adata
# Out:
# AnnData object with n_obs × n_vars = 15681 × 1000
#     obs: 'batch', 'study', 'cell_type', 'size_factors'

# %%
query = np.array([s in target_batches for s in adata.obs[batch_key]])
adata_ref_full = adata[~query].copy()
adata_ref = adata_ref_full[~adata_ref_full.obs[cell_type_key].isin(leave_out_cell_types)].copy()
adata_query = adata[query].copy()
# Out:
# /home/marco/.pyenv/versions/scvi_test/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %%
adata_ref
adata_ref.obs[cell_type_key].unique()
# Out:
# AnnData object with n_obs × n_vars = 7584 × 1000
#     obs: 'batch', 'study', 'cell_type', 'size_factors'

# %%
scvi.data.setup_anndata(adata_ref, batch_key=batch_key, labels_key=cell_type_key)
# Out:
# INFO      Using batches from adata.obs["study"]
# INFO      Using labels from adata.obs["cell_type"]
# INFO      Using data from adata.X
# INFO      Computing library size prior per batch
# INFO      Successfully registered anndata object containing 7584 cells, 1000 vars, 3 batches,
#           7 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0
#           extra continuous covariates.
# INFO      Please do not further modify adata until model is trained.
# /home/marco/.pyenv/versions/scvi_test/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /home/marco/.pyenv/versions/scvi_test/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /home/marco/.pyenv/versions/scvi_test/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %% [markdown]
# # Create SCANVI model and train

# %%
vae = scvi.model.SCANVI(
    adata_ref,
    "Unknown",
    n_layers=2,
    use_cuda=True,
    encode_covariates=True,
    deeply_inject_covariates=deep_inject,
    use_layer_norm="both",
    use_batch_norm="none",
    use_observed_lib_size=True,
)

# %%
print(adata_ref.obs[cell_type_key].unique())
print(adata_ref.obs["_scvi_labels"].unique())
print(adata_ref.obs[batch_key].unique())
print(adata_ref.obs["_scvi_batch"].unique())
print("Labelled Indices: ", vae._labeled_indices.shape[0])
print("Unlabelled Indices: ", vae._unlabeled_indices.shape[0])
# Out:
# ['Pancreas Endothelial', 'Pancreas Acinar', 'Pancreas Beta', 'Pancreas Delta', 'Pancreas Stellate', 'Pancreas Ductal', 'Pancreas Gamma']
# Categories (7, object): ['Pancreas Endothelial', 'Pancreas Acinar', 'Pancreas Beta', 'Pancreas Delta', 'Pancreas Stellate', 'Pancreas Ductal', 'Pancreas Gamma']
# [4 0 1 2 6 3 5]
# ['Pancreas inDrop', 'Pancreas CelSeq', 'Pancreas Fluidigm C1']
# Categories (3, object): ['Pancreas inDrop', 'Pancreas CelSeq', 'Pancreas Fluidigm C1']
# [2 0 1]
# Labelled Indices:  7584
# Unlabelled Indices:  0

# %%
ref_time = time.time()
vae.train(
    n_epochs_unsupervised=n_epochs_vae,
    n_epochs_semisupervised=n_epochs_scanvi,
    unsupervised_trainer_kwargs=dict(early_stopping_kwargs=early_stopping_kwargs),
    semisupervised_trainer_kwargs=dict(metrics_to_monitor=["elbo", "accuracy"],
                                       early_stopping_kwargs=early_stopping_kwargs_scanvi),
    frequency=1
)
ref_time = time.time() - ref_time
# Out:
# INFO      Training Unsupervised Trainer for 500 epochs.
# INFO      Training SemiSupervised Trainer for 300 epochs.
# INFO      KL warmup for 400 epochs
# Training...:   0%|          | 0/500 [00:00<?, ?it/s]
# /home/marco/.pyenv/versions/scvi_test/lib/python3.7/site-packages/scvi/core/distributions/_negative_binomial.py:424: UserWarning: The value argument must be within the support of the distribution
#   UserWarning,
# Training...:  20%|█▉        | 99/500 [00:47<03:05,  2.16it/s]INFO      Reducing LR on epoch 99.
# Training...:  31%|███▏      | 157/500 [01:18<03:01,  1.89it/s]INFO      Reducing LR on epoch 157.
# Training...:  32%|███▏      | 159/500 [01:19<02:55,  1.95it/s]INFO
#           Stopping early: no improvement of more than 0 nats in 10 epochs
# INFO      If the early stopping criterion is too strong, please instantiate it with different
#           parameters in the train method.
# Training...:  32%|███▏      | 159/500 [01:20<02:51,  1.98it/s]
# INFO      Training is still in warming up phase. If your applications rely on the posterior
#           quality, consider training for more epochs or reducing the kl warmup.
# INFO      Training time:  55 s. / 500 epochs
# INFO      KL warmup phase exceeds overall training phaseIf your applications rely on the
#           posterior quality, consider training for more epochs or reducing the kl warmup.
# INFO      KL warmup for 400 epochs
# Training...:  15%|█▌        | 46/300 [01:27<07:26,  1.76s/it]INFO      Reducing LR on epoch 46.
# Training...:  16%|█▌        | 48/300 [01:31<07:15,  1.73s/it]INFO
#           Stopping early: no improvement of more than 0.001 nats in 10 epochs
# INFO      If the early stopping criterion is too strong, please instantiate it with different
#           parameters in the train method.
# Training...:  16%|█▌        | 48/300 [01:33<08:08,  1.94s/it]
# INFO      Training is still in warming up phase. If your applications rely on the posterior
#           quality, consider training for more epochs or reducing the kl warmup.
# INFO      Training time:  55 s. / 300 epochs

# %% [markdown]
# # Reference Evaluation

# %%
ref_predictions = vae.predict(adata_ref)
adata_ref.obsm["X_scANVI"] = vae.get_latent_representation()
adata_ref.obs["predictions"] = vae.predict()
print("Acc: {}".format(np.mean(ref_predictions == adata_ref.obs.cell_type)))
# Out:
# Acc: 0.9671677215189873

# %%
plt.figure()
plt.plot(vae.trainer.history['accuracy_full_dataset'][2:], label="ACC")
plt.title("ACC")
plt.legend()

# %%
plt.figure()
plt.plot(vae.trainer.history['elbo_full_dataset'][2:], label="ELBO")
plt.title("ELBO")
plt.legend()

# %%
sc.pp.neighbors(adata_ref, use_rep="X_scANVI")
sc.tl.leiden(adata_ref)
sc.tl.umap(adata_ref)
plt.figure()
sc.pl.umap(
    adata_ref,
    color=[batch_key, cell_type_key],
    frameon=False,
    ncols=1,
)
# Out:
# /home/marco/.pyenv/versions/scvi_test/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# ... storing 'predictions' as categorical

# %%
adata_ref.write_h5ad(filename=f'{dir_path}reference_data.h5ad')
torch.save(vae.model.state_dict(), f'{dir_path}reference_model_state_dict')
ref_path = f'{dir_path}ref_model/'
if not os.path.exists(ref_path):
    os.makedirs(ref_path)
vae.save(ref_path, overwrite=True)

# %% [markdown]
# # Run surgery on first query batch

# %%
model_1 = scvi.model.SCANVI.load_query_data(
    adata_query_1,
    ref_path,
    use_cuda=True,
    freeze_batchnorm_encoder=True,
    freeze_batchnorm_decoder=True,
    freeze_expression=True,
)
# Out:
# INFO      Using data from adata.X
# INFO      Computing library size prior per batch
# INFO      Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO      Successfully registered anndata object containing 2961 cells, 1000 vars, 4 batches,
#           8 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0
#           extra continuous covariates.
# /home/marco/.pyenv/versions/scvi_test/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %%
print(adata_query_1.obs[cell_type_key].unique())
print(adata_query_1.obs["_scvi_labels"].unique())
print(adata_query_1.obs[batch_key].unique())
print(adata_query_1.obs["_scvi_batch"].unique())
model_1._unlabeled_indices = np.arange(adata_query_1.n_obs)
model_1._labeled_indices = []
print("Labelled Indices: ", len(model_1._labeled_indices))
print("Unlabelled Indices: ", model_1._unlabeled_indices.shape[0])
# Out:
# ['Pancreas Beta', 'Pancreas Acinar', 'Pancreas Gamma', 'Pancreas Alpha', 'Pancreas Ductal', 'Pancreas Delta', 'Pancreas Stellate', 'Pancreas Endothelial']
# Categories (8, object): ['Pancreas Beta', 'Pancreas Acinar', 'Pancreas Gamma', 'Pancreas Alpha', 'Pancreas Ductal', 'Pancreas Delta', 'Pancreas Stellate', 'Pancreas Endothelial']
# [1 0 5 7 3 2 6 4]
# ['Pancreas SS2']
# Categories (1, object): ['Pancreas SS2']
# [3]
# Labelled Indices:  0
# Unlabelled Indices:  2961

# %%
query_1_time = time.time()
model_1.train(
    n_epochs_semisupervised=n_epochs_surgery,
    train_base_model=False,
    semisupervised_trainer_kwargs=dict(metrics_to_monitor=["accuracy"], 
                                       weight_decay=0
                                      ),
    frequency=1
)
query_1_time = time.time() - query_1_time
# Out:
# INFO      Training Unsupervised Trainer for 400 epochs.
# INFO      Training SemiSupervised Trainer for 300 epochs.
# INFO      KL warmup phase exceeds overall training phaseIf your applications rely on the
#           posterior quality, consider training for more epochs or reducing the kl warmup.
# INFO      KL warmup for 400 epochs
# Training...: 100%|██████████| 300/300 [01:52<00:00,  2.67it/s]
# INFO      Training is still in warming up phase. If your applications rely on the posterior
#           quality, consider training for more epochs or reducing the kl warmup.
# INFO      Training time:  74 s. / 300 epochs

# %% [markdown]
# # Evaluation Surgery on Query1

# %%
adata_query_1.obsm["X_scANVI"] = model_1.get_latent_representation()
adata_query_1.obs["predictions"] = model_1.predict()
query_1_predictions = model_1.predict()
print("Acc: {}".format(np.mean(query_1_predictions == adata_query_1.obs.cell_type)))
# Out:
# Acc: 0.49206349206349204

# %%
plt.figure()
plt.plot(model_1.trainer.history['accuracy_full_dataset'][2:], label="ACC")
plt.title("ACC")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6e4f85048e2c> in <module>
# ----> 1 plt.figure()
#       2 plt.plot(model_1.trainer.history['accuracy_full_dataset'][2:], label="ACC")
#       3 plt.title("ACC")
#       4 plt.legend()
#
# NameError: name 'plt' is not defined

# %%
sc.pp.neighbors(adata_query_1, use_rep="X_scANVI")
sc.tl.leiden(adata_query_1)
sc.tl.umap(adata_query_1)
plt.figure()
sc.pl.umap(
    adata_query_1,
    color=[batch_key, "cell_type"],
    frameon=False,
    ncols=1,
)

# %%
adata_query_1.write_h5ad(filename=f'{dir_path}query_1_data.h5ad')

# %% [markdown]
# # Evaluation Query1 on reference

# %%
adata_full_1 = adata_ref.concatenate(adata_query_1)
adata_full_1.uns["_scvi"] = adata_query_1.uns["_scvi"]
print(adata_full_1.obs[cell_type_key].unique())
print(adata_full_1.obs["_scvi_labels"].unique())
print(adata_full_1.obs[batch_key].unique())
print(adata_full_1.obs["_scvi_batch"].unique())
adata_full_1.obsm["X_scANVI"] = model_1.get_latent_representation(adata=adata_full_1)

# %%
full_1_predictions = model_1.predict(adata_full_1)
print("Acc: {}".format(np.mean(full_1_predictions == adata_full_1.obs.cell_type)))

# %%
sc.pp.neighbors(adata_full_1, use_rep="X_scANVI")
sc.tl.leiden(adata_full_1)
sc.tl.umap(adata_full_1)
plt.figure()
sc.pl.umap(
    adata_full_1,
    color=[batch_key, cell_type_key],
    frameon=False,
    ncols=1,
)

# %%
sc.pl.umap(
    adata_full_1[adata_ref.n_obs:],
    color=["predictions", cell_type_key],
    frameon=False,
    ncols=1,
)

# %%
adata_full_1.write_h5ad(filename=f'{dir_path}full_1_data.h5ad')
torch.save(model_1.model.state_dict(), f'{dir_path}surgery_1_model_state_dict')
surgery_1_path = f'{dir_path}surg_1_model/'
if not os.path.exists(surgery_1_path):
    os.makedirs(surgery_1_path)
model_1.save(surgery_1_path, overwrite=True)

# %% [markdown]
# # Run surgery on second query batch

# %%
model_2 = scvi.model.SCANVI.load_query_data(
    adata_query_2,
    surgery_1_path,
    use_cuda=True,
    freeze_batchnorm_encoder=True,
    freeze_batchnorm_decoder=True,
    freeze_expression=True,
)

# %%
print(adata_query_2.obs[cell_type_key].unique())
print(adata_query_2.obs["_scvi_labels"].unique())
print(adata_query_2.obs[batch_key].unique())
print(adata_query_2.obs["_scvi_batch"].unique())
model_2._unlabeled_indices = np.arange(adata_query_2.n_obs)
model_2._labeled_indices = []
print("Labelled Indices: ", len(model_2._labeled_indices))
print("Unlabelled Indices: ", model_2._unlabeled_indices.shape[0])

# %%
query_2_time = time.time()
model_2.train(
    n_epochs_semisupervised=n_epochs_surgery,
    train_base_model=False,
    semisupervised_trainer_kwargs=dict(metrics_to_monitor=["accuracy"],
                                       weight_decay=0),
    frequency=1
)
query_2_time = time.time() - query_2_time

# %% [markdown]
# # Evaluation Surgery on Query2

# %%
plt.plot(model_2.trainer.history['accuracy_full_dataset'][2:], label="ACC")
plt.title("ACC")
plt.legend()

# %%
adata_query_2.obsm["X_scANVI"] = model_2.get_latent_representation()
adata_query_2.obs["predictions"] = model_2.predict()
query_predictions = model_2.predict()
print("Acc: {}".format(np.mean(query_predictions == adata_query_2.obs.cell_type)))

# %%
sc.pp.neighbors(adata_query_2, use_rep="X_scANVI")
sc.tl.leiden(adata_query_2)
sc.tl.umap(adata_query_2)
plt.figure()
sc.pl.umap(
    adata_query_2,
    color=[batch_key, "cell_type"],
    frameon=False,
    ncols=1,
)

# %%
adata_query_2.write_h5ad(filename=f'{dir_path}query_2_data.h5ad')

# %% [markdown]
# # Evaluation Query1 and Query2 on Reference

# %%
adata_full_2 = adata_full_1.concatenate(adata_query_2)
adata_full_2.uns["_scvi"] = adata_query_2.uns["_scvi"]
print(adata_full_2.obs[cell_type_key].unique())
print(adata_full_2.obs["_scvi_labels"].unique())
print(adata_full_2.obs[batch_key].unique())
print(adata_full_2.obs["_scvi_batch"].unique())
adata_full_2.obsm["X_scANVI"] = model_2.get_latent_representation(adata=adata_full_2)
full_predictions = model_2.predict(adata_full_2)
print("Acc: {}".format(np.mean(full_predictions == adata_full_2.obs.cell_type)))

# %%
sc.pp.neighbors(adata_full_2, use_rep="X_scANVI")
sc.tl.leiden(adata_full_2)
sc.tl.umap(adata_full_2)
plt.figure()
sc.pl.umap(
    adata_full_2,
    color=[batch_key, cell_type_key],
    frameon=False,
    ncols=1,
)

# %%
sc.pl.umap(
    adata_full_2[adata_ref.n_obs:],
    color=["predictions", cell_type_key],
    frameon=False,
    ncols=1,
)

# %%
adata_full_2.write_h5ad(filename=f'{dir_path}full_2_data.h5ad')
torch.save(model_2.model.state_dict(), f'{dir_path}surgery_2_model_state_dict')
surgery_2_path = f'{dir_path}surg_2_model/'
if not os.path.exists(surgery_2_path):
    os.makedirs(surgery_2_path)
model_2.save(surgery_2_path, overwrite=True)

# %%
times = dict()
times["ref_time"] = ref_time
times["query_1_time"] = query_1_time
times["query_2_time"] = query_2_time
times["full_time"] = ref_time + query_1_time + query_2_time
with open(f'{dir_path}results_times.txt', 'w') as filehandle:
    json.dump(times, filehandle)
